# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 595

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
cityname_list = []
lat_list = []
lng_list = []
maxtemp_list = []
humidity_list = []
cloudiness_list = []
windspeed_list = []
country_list = []
date_list = []

record = 0
sets = 1

print("Beginning Data Retrieval")
print("-----------------------------")

base_url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = base_url + "appid=" + weather_api_key + "&units=" + units + "&q="

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        cityname_list.append(response["name"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])    
        maxtemp_list.append(response["main"]["temp_max"])
        humidity_list.append(response["main"]["humidity"])
        cloudiness_list.append(response["clouds"]["all"])
        windspeed_list.append(response["wind"]["speed"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
    
        if record > 49:
            record = 0
            sets = sets + 1
    
        else:
            record = record + 1
        
        print(f"Processing Record {record} of Set {sets} | {city}")
    
    except:
        print(f"City not found. Skipping... {city}.")
        
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | coihaique
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | northam
# Processing Record 4 of Set 1 | nome
# City not found. Skipping... illoqqortoormiut.
# Processing Record 5 of Set 1 | fuerte olimpo
# City not found. Skipping... taolanaro.
# Processing Record 6 of Set 1 | whithorn
# Processing Record 7 of Set 1 | kalavai
# Processing Record 8 of Set 1 | sharjah
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | usinsk
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | wanning
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | palmer
# Processing Record 18 of Set 1 | faanui
# City not found. Skipping... amderma.
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | cabra
# Processing Record 21 of Set 1 | gainesville
# Processing Record 22 of Set 1 | muros
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | fare
# Processing Record 25 of Set 1 | iqaluit
# Processing Record 26 of Set 1 | balsas
# Processing Record 27 of Set 1 | polunochnoye
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | dhidhdhoo
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | dawson creek
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | zhanaozen
# Processing Record 38 of Set 1 | san quintin
# Processing Record 39 of Set 1 | kyra
# Processing Record 40 of Set 1 | busselton
# City not found. Skipping... samusu.
# Processing Record 41 of Set 1 | kapaa
# City not found. Skipping... bolungarvik.
# City not found. Skipping... tabiauea.
# Processing Record 42 of Set 1 | batagay
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | provideniya
# Processing Record 45 of Set 1 | kiunga
# City not found. Skipping... vaitupu.
# Processing Record 46 of Set 1 | mount isa
# Processing Record 47 of Set 1 | duku
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 0 of Set 2 | dikson
# Processing Record 1 of Set 2 | henties bay
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | margate
# Processing Record 6 of Set 2 | hambantota
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | kulachi
# Processing Record 10 of Set 2 | padang
# City not found. Skipping... mocambique.
# Processing Record 11 of Set 2 | kem
# City not found. Skipping... bandar-e torkaman.
# Processing Record 12 of Set 2 | mahebourg
# City not found. Skipping... belushya guba.
# Processing Record 13 of Set 2 | harrismith
# City not found. Skipping... marcona.
# Processing Record 14 of Set 2 | cidreira
# Processing Record 15 of Set 2 | huicungo
# Processing Record 16 of Set 2 | kahului
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | tiarei
# Processing Record 19 of Set 2 | namibe
# Processing Record 20 of Set 2 | chuy
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | tura
# Processing Record 23 of Set 2 | cerro largo
# Processing Record 24 of Set 2 | meridian
# City not found. Skipping... coulihaut.
# City not found. Skipping... dinsor.
# Processing Record 25 of Set 2 | alofi
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | komsomolskiy
# Processing Record 28 of Set 2 | torbay
# Processing Record 29 of Set 2 | jumla
# Processing Record 30 of Set 2 | hilo
# Processing Record 31 of Set 2 | vestmannaeyjar
# City not found. Skipping... linchuan.
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | kodiak
# Processing Record 34 of Set 2 | port elizabeth
# Processing Record 35 of Set 2 | belmonte
# Processing Record 36 of Set 2 | haicheng
# Processing Record 37 of Set 2 | mount gambier
# Processing Record 38 of Set 2 | sola
# City not found. Skipping... attawapiskat.
# Processing Record 39 of Set 2 | nyurba
# Processing Record 40 of Set 2 | aklavik
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | luderitz
# Processing Record 43 of Set 2 | alpena
# Processing Record 44 of Set 2 | sept-iles
# Processing Record 45 of Set 2 | torrevieja
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | erzin
# Processing Record 48 of Set 2 | zalantun
# Processing Record 49 of Set 2 | gazanjyk
# Processing Record 50 of Set 2 | victoria
# Processing Record 0 of Set 3 | matara
# Processing Record 1 of Set 3 | urdoma
# Processing Record 2 of Set 3 | naze
# Processing Record 3 of Set 3 | kyaiklat
# Processing Record 4 of Set 3 | ostrovnoy
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | ponta delgada
# Processing Record 7 of Set 3 | mehamn
# City not found. Skipping... mrirt.
# Processing Record 8 of Set 3 | saint-philippe
# Processing Record 9 of Set 3 | tiksi
# Processing Record 10 of Set 3 | pangnirtung
# Processing Record 11 of Set 3 | verkhnevilyuysk
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | adrar
# Processing Record 14 of Set 3 | fethiye
# Processing Record 15 of Set 3 | turukhansk
# Processing Record 16 of Set 3 | leh
# Processing Record 17 of Set 3 | talnakh
# Processing Record 18 of Set 3 | wentzville
# Processing Record 19 of Set 3 | dingle
# Processing Record 20 of Set 3 | kemijarvi
# Processing Record 21 of Set 3 | celestun
# Processing Record 22 of Set 3 | beringovskiy
# Processing Record 23 of Set 3 | avera
# City not found. Skipping... doctor pedro p. pena.
# Processing Record 24 of Set 3 | elat
# Processing Record 25 of Set 3 | camana
# Processing Record 26 of Set 3 | pevek
# Processing Record 27 of Set 3 | leningradskiy
# Processing Record 28 of Set 3 | cayenne
# Processing Record 29 of Set 3 | lata
# Processing Record 30 of Set 3 | nanortalik
# Processing Record 31 of Set 3 | ribeira grande
# Processing Record 32 of Set 3 | cabo san lucas
# Processing Record 33 of Set 3 | ponta do sol
# Processing Record 34 of Set 3 | eyl
# Processing Record 35 of Set 3 | tiznit
# Processing Record 36 of Set 3 | beyneu
# Processing Record 37 of Set 3 | takaka
# Processing Record 38 of Set 3 | calama
# Processing Record 39 of Set 3 | saint-georges
# Processing Record 40 of Set 3 | valcourt
# Processing Record 41 of Set 3 | kidal
# Processing Record 42 of Set 3 | trairi
# Processing Record 43 of Set 3 | ferme-neuve
# Processing Record 44 of Set 3 | airai
# Processing Record 45 of Set 3 | the valley
# Processing Record 46 of Set 3 | esperance
# Processing Record 47 of Set 3 | carutapera
# Processing Record 48 of Set 3 | mahanoro
# Processing Record 49 of Set 3 | saint-francois
# Processing Record 50 of Set 3 | santa cruz
# Processing Record 0 of Set 4 | pouembout
# Processing Record 1 of Set 4 | arraial do cabo
# Processing Record 2 of Set 4 | ilulissat
# Processing Record 3 of Set 4 | srednekolymsk
# Processing Record 4 of Set 4 | svetlogorsk
# Processing Record 5 of Set 4 | nabire
# Processing Record 6 of Set 4 | coari
# Processing Record 7 of Set 4 | kavieng
# City not found. Skipping... cheuskiny.
# Processing Record 8 of Set 4 | baykit
# Processing Record 9 of Set 4 | east london
# Processing Record 10 of Set 4 | antofagasta
# Processing Record 11 of Set 4 | narsaq
# City not found. Skipping... barentsburg.
# Processing Record 12 of Set 4 | poplar bluff
# Processing Record 13 of Set 4 | shetpe
# Processing Record 14 of Set 4 | deputatskiy
# Processing Record 15 of Set 4 | mahbubnagar
# Processing Record 16 of Set 4 | kruisfontein
# Processing Record 17 of Set 4 | bodden town
# Processing Record 18 of Set 4 | upernavik
# Processing Record 19 of Set 4 | weyburn
# Processing Record 20 of Set 4 | flinders
# Processing Record 21 of Set 4 | hasaki
# Processing Record 22 of Set 4 | japura
# Processing Record 23 of Set 4 | robertsport
# Processing Record 24 of Set 4 | shenjiamen
# City not found. Skipping... juifang.
# Processing Record 25 of Set 4 | cherskiy
# Processing Record 26 of Set 4 | puerto escondido
# Processing Record 27 of Set 4 | nago
# City not found. Skipping... yomitan.
# Processing Record 28 of Set 4 | kargasok
# Processing Record 29 of Set 4 | wuda
# Processing Record 30 of Set 4 | coquimbo
# Processing Record 31 of Set 4 | tuatapere
# Processing Record 32 of Set 4 | namatanai
# Processing Record 33 of Set 4 | longyearbyen
# Processing Record 34 of Set 4 | zhuanghe
# Processing Record 35 of Set 4 | kondrovo
# Processing Record 36 of Set 4 | souillac
# Processing Record 37 of Set 4 | salalah
# Processing Record 38 of Set 4 | varzea grande
# Processing Record 39 of Set 4 | alice springs
# City not found. Skipping... khonuu.
# Processing Record 40 of Set 4 | orbetello
# Processing Record 41 of Set 4 | champerico
# Processing Record 42 of Set 4 | isangel
# Processing Record 43 of Set 4 | bairiki
# Processing Record 44 of Set 4 | loding
# Processing Record 45 of Set 4 | kieta
# Processing Record 46 of Set 4 | gawler
# Processing Record 47 of Set 4 | luang prabang
# Processing Record 48 of Set 4 | yarmouth
# Processing Record 49 of Set 4 | aquiraz
# Processing Record 50 of Set 4 | norman wells
# Processing Record 0 of Set 5 | eureka
# Processing Record 1 of Set 5 | nouadhibou
# Processing Record 2 of Set 5 | am timan
# Processing Record 3 of Set 5 | plettenberg bay
# Processing Record 4 of Set 5 | dunedin
# Processing Record 5 of Set 5 | fagersta
# Processing Record 6 of Set 5 | freetown
# Processing Record 7 of Set 5 | flin flon
# Processing Record 8 of Set 5 | constitucion
# Processing Record 9 of Set 5 | ulladulla
# Processing Record 10 of Set 5 | khandyga
# Processing Record 11 of Set 5 | ancud
# Processing Record 12 of Set 5 | vostok
# Processing Record 13 of Set 5 | porgera
# Processing Record 14 of Set 5 | vikhorevka
# Processing Record 15 of Set 5 | semey
# Processing Record 16 of Set 5 | labytnangi
# City not found. Skipping... cazaje.
# Processing Record 17 of Set 5 | port moresby
# City not found. Skipping... litoral del san juan.
# Processing Record 18 of Set 5 | pemba
# Processing Record 19 of Set 5 | ca mau
# City not found. Skipping... mutsamudu.
# Processing Record 20 of Set 5 | san cristobal
# Processing Record 21 of Set 5 | kavaratti
# Processing Record 22 of Set 5 | carballo
# Processing Record 23 of Set 5 | montrose
# Processing Record 24 of Set 5 | ayagoz
# City not found. Skipping... golden rock.
# Processing Record 25 of Set 5 | green river
# Processing Record 26 of Set 5 | ahipara
# Processing Record 27 of Set 5 | atar
# Processing Record 28 of Set 5 | sitka
# Processing Record 29 of Set 5 | lavrentiya
# Processing Record 30 of Set 5 | lhokseumawe
# Processing Record 31 of Set 5 | qui nhon
# Processing Record 32 of Set 5 | pontianak
# Processing Record 33 of Set 5 | kuandian
# Processing Record 34 of Set 5 | saldanha
# Processing Record 35 of Set 5 | savannah bight
# Processing Record 36 of Set 5 | aksarka
# Processing Record 37 of Set 5 | severo-kurilsk
# Processing Record 38 of Set 5 | tuy hoa
# City not found. Skipping... grand river south east.
# City not found. Skipping... kuche.
# Processing Record 39 of Set 5 | saint-joseph
# Processing Record 40 of Set 5 | tabou
# Processing Record 41 of Set 5 | arecibo
# Processing Record 42 of Set 5 | harper
# City not found. Skipping... cicarlau.
# Processing Record 43 of Set 5 | mumbwa
# Processing Record 44 of Set 5 | mangit
# Processing Record 45 of Set 5 | farafangana
# Processing Record 46 of Set 5 | bethel
# Processing Record 47 of Set 5 | nakamura
# Processing Record 48 of Set 5 | charters towers
# Processing Record 49 of Set 5 | cumanayagua
# Processing Record 50 of Set 5 | aqtobe
# Processing Record 0 of Set 6 | pangai
# Processing Record 1 of Set 6 | popondetta
# City not found. Skipping... samalaeulu.
# Processing Record 2 of Set 6 | maarianhamina
# Processing Record 3 of Set 6 | glodeanu-silistea
# City not found. Skipping... sorvag.
# Processing Record 4 of Set 6 | vanavara
# Processing Record 5 of Set 6 | havelock
# Processing Record 6 of Set 6 | preobrazheniye
# Processing Record 7 of Set 6 | camopi
# Processing Record 8 of Set 6 | uusikaupunki
# Processing Record 9 of Set 6 | goundam
# Processing Record 10 of Set 6 | lasa
# Processing Record 11 of Set 6 | panguna
# Processing Record 12 of Set 6 | marawi
# Processing Record 13 of Set 6 | samarai
# Processing Record 14 of Set 6 | alihe
# Processing Record 15 of Set 6 | yar-sale
# Processing Record 16 of Set 6 | glyadyanskoye
# City not found. Skipping... umzimvubu.
# Processing Record 17 of Set 6 | sioux lookout
# Processing Record 18 of Set 6 | kicevo
# Processing Record 19 of Set 6 | vestmanna
# Processing Record 20 of Set 6 | krasnoselkup
# Processing Record 21 of Set 6 | clyde river
# Processing Record 22 of Set 6 | poso
# Processing Record 23 of Set 6 | tibu
# Processing Record 24 of Set 6 | severodvinsk
# City not found. Skipping... karamea.
# Processing Record 25 of Set 6 | goderich
# Processing Record 26 of Set 6 | sechura
# Processing Record 27 of Set 6 | kushiro
# Processing Record 28 of Set 6 | college
# City not found. Skipping... tsihombe.
# Processing Record 29 of Set 6 | hervey bay
# Processing Record 30 of Set 6 | syracuse
# Processing Record 31 of Set 6 | inta
# Processing Record 32 of Set 6 | pasni
# Processing Record 33 of Set 6 | pedernales
# Processing Record 34 of Set 6 | scarborough
# Processing Record 35 of Set 6 | ust-tsilma
# Processing Record 36 of Set 6 | urengoy
# Processing Record 37 of Set 6 | la colmena
# Processing Record 38 of Set 6 | kloulklubed
# City not found. Skipping... ust-kamchatsk.
# Processing Record 39 of Set 6 | saint george
# Processing Record 40 of Set 6 | nanakuli
# Processing Record 41 of Set 6 | jesup
# Processing Record 42 of Set 6 | fairbanks
# Processing Record 43 of Set 6 | cabedelo
# Processing Record 44 of Set 6 | inhambane
# Processing Record 45 of Set 6 | port blair
# Processing Record 46 of Set 6 | mercedes
# Processing Record 47 of Set 6 | meulaboh
# Processing Record 48 of Set 6 | marystown
# Processing Record 49 of Set 6 | auki
# Processing Record 50 of Set 6 | ulaanbaatar
# Processing Record 0 of Set 7 | rondonopolis
# Processing Record 1 of Set 7 | abu samrah
# City not found. Skipping... mys shmidta.
# Processing Record 2 of Set 7 | de panne
# Processing Record 3 of Set 7 | gizo
# Processing Record 4 of Set 7 | marzuq
# Processing Record 5 of Set 7 | maryville
# Processing Record 6 of Set 7 | emba
# Processing Record 7 of Set 7 | geraldton
# Processing Record 8 of Set 7 | ouegoa
# Processing Record 9 of Set 7 | vardo
# Processing Record 10 of Set 7 | korla
# Processing Record 11 of Set 7 | san joaquin
# Processing Record 12 of Set 7 | key west
# Processing Record 13 of Set 7 | marsh harbour
# Processing Record 14 of Set 7 | kununurra
# City not found. Skipping... umm durman.
# Processing Record 15 of Set 7 | mayo
# Processing Record 16 of Set 7 | fortuna
# Processing Record 17 of Set 7 | saint-ambroise
# Processing Record 18 of Set 7 | kenai
# Processing Record 19 of Set 7 | sinnamary
# Processing Record 20 of Set 7 | laguna
# Processing Record 21 of Set 7 | camacari
# Processing Record 22 of Set 7 | aktau
# Processing Record 23 of Set 7 | xining
# Processing Record 24 of Set 7 | makubetsu
# Processing Record 25 of Set 7 | tonj
# City not found. Skipping... karauzyak.
# Processing Record 26 of Set 7 | mahibadhoo
# Processing Record 27 of Set 7 | pacific grove
# Processing Record 28 of Set 7 | bathsheba
# Processing Record 29 of Set 7 | moose factory
# Processing Record 30 of Set 7 | coffs harbour
# Processing Record 31 of Set 7 | berlevag
# Processing Record 32 of Set 7 | hersbruck
# Processing Record 33 of Set 7 | sayyan
# Processing Record 34 of Set 7 | trojes
# Processing Record 35 of Set 7 | zelenoborskiy
# Processing Record 36 of Set 7 | katobu
# Processing Record 37 of Set 7 | beloha
# Processing Record 38 of Set 7 | paamiut
# Processing Record 39 of Set 7 | bengkulu
# Processing Record 40 of Set 7 | poum
# Processing Record 41 of Set 7 | voyvozh
# Processing Record 42 of Set 7 | mosquera
# Processing Record 43 of Set 7 | kota belud
# Processing Record 44 of Set 7 | taldan
# Processing Record 45 of Set 7 | nalut
# City not found. Skipping... ruatoria.
# Processing Record 46 of Set 7 | thoen
# Processing Record 47 of Set 7 | yangambi
# Processing Record 48 of Set 7 | estrela
# Processing Record 49 of Set 7 | linxia
# Processing Record 50 of Set 7 | grand gaube
# City not found. Skipping... lolua.
# Processing Record 0 of Set 8 | gao
# Processing Record 1 of Set 8 | torit
# Processing Record 2 of Set 8 | comalcalco
# Processing Record 3 of Set 8 | myanaung
# Processing Record 4 of Set 8 | vanimo
# Processing Record 5 of Set 8 | nishihara
# Processing Record 6 of Set 8 | dwarka
# Processing Record 7 of Set 8 | rio gallegos
# Processing Record 8 of Set 8 | port hardy
# Processing Record 9 of Set 8 | ochakiv
# Processing Record 10 of Set 8 | kaitangata
# Processing Record 11 of Set 8 | la rioja
# Processing Record 12 of Set 8 | los llanos de aridane
# Processing Record 13 of Set 8 | kizukuri
# Processing Record 14 of Set 8 | bukachacha
# Processing Record 15 of Set 8 | bansgaon
# Processing Record 16 of Set 8 | lake havasu city
# Processing Record 17 of Set 8 | lockhart
# Processing Record 18 of Set 8 | shingu
# Processing Record 19 of Set 8 | ercis
# Processing Record 20 of Set 8 | maurawan
# Processing Record 21 of Set 8 | broadstairs
# Processing Record 22 of Set 8 | chokurdakh
# Processing Record 23 of Set 8 | boyolangu
# Processing Record 24 of Set 8 | poronaysk
# Processing Record 25 of Set 8 | urumqi
# Processing Record 26 of Set 8 | makakilo city
# Processing Record 27 of Set 8 | gariaband
# Processing Record 28 of Set 8 | egvekinot
# City not found. Skipping... nizhneyansk.
# Processing Record 29 of Set 8 | riviere-au-renard
# Processing Record 30 of Set 8 | necochea
# Processing Record 31 of Set 8 | ixtapa
# Processing Record 32 of Set 8 | povenets
# Processing Record 33 of Set 8 | olafsvik
# Processing Record 34 of Set 8 | dong hoi
# Processing Record 35 of Set 8 | san felipe
# Processing Record 36 of Set 8 | sona
# Processing Record 37 of Set 8 | taos
# Processing Record 38 of Set 8 | tambovka
# Processing Record 39 of Set 8 | begoro
# Processing Record 40 of Set 8 | pinotepa nacional
# Processing Record 41 of Set 8 | surgut
# Processing Record 42 of Set 8 | biltine
# Processing Record 43 of Set 8 | buin
# Processing Record 44 of Set 8 | shimoda
# Processing Record 45 of Set 8 | vieques
# Processing Record 46 of Set 8 | careiro da varzea
# City not found. Skipping... warqla.
# Processing Record 47 of Set 8 | waipawa
# Processing Record 48 of Set 8 | mayumba
# Processing Record 49 of Set 8 | klyuchi
# City not found. Skipping... uwayl.
# Processing Record 50 of Set 8 | alexandria
# Processing Record 0 of Set 9 | coahuayana
# Processing Record 1 of Set 9 | caloundra
# City not found. Skipping... temaraia.
# Processing Record 2 of Set 9 | viedma
# Processing Record 3 of Set 9 | preeceville
# Processing Record 4 of Set 9 | labuhan
# Processing Record 5 of Set 9 | cumberland
# City not found. Skipping... palabuhanratu.
# Processing Record 6 of Set 9 | gayeri
# Processing Record 7 of Set 9 | ulsteinvik
# Processing Record 8 of Set 9 | okha
# Processing Record 9 of Set 9 | shache
# Processing Record 10 of Set 9 | chimbote
# Processing Record 11 of Set 9 | cordoba
# Processing Record 12 of Set 9 | rocha
# Processing Record 13 of Set 9 | saint-augustin
# Processing Record 14 of Set 9 | mandera
# Processing Record 15 of Set 9 | kapuskasing
# Processing Record 16 of Set 9 | taltal
# Processing Record 17 of Set 9 | novaya igirma
# Processing Record 18 of Set 9 | klaksvik
# Processing Record 19 of Set 9 | bahia honda
# Processing Record 20 of Set 9 | san juan
# Processing Record 21 of Set 9 | ust-kut
# Processing Record 22 of Set 9 | paratinga
# Processing Record 23 of Set 9 | hobyo
# Processing Record 24 of Set 9 | mecca
# Processing Record 25 of Set 9 | springfield
# Processing Record 26 of Set 9 | parrita
# Processing Record 27 of Set 9 | zatoka
# Processing Record 28 of Set 9 | turayf
# Processing Record 29 of Set 9 | grindavik
# Processing Record 30 of Set 9 | evensk
# Processing Record 31 of Set 9 | roald
# Processing Record 32 of Set 9 | tabuk
# Processing Record 33 of Set 9 | dzhubga
# Processing Record 34 of Set 9 | sainte-suzanne
# City not found. Skipping... saleaula.
# Processing Record 35 of Set 9 | port-cartier
# Processing Record 36 of Set 9 | seoul
# Processing Record 37 of Set 9 | ayan
# Processing Record 38 of Set 9 | tahta
# Processing Record 39 of Set 9 | te anau
# Processing Record 40 of Set 9 | isla mujeres
# Processing Record 41 of Set 9 | santa rosa
# Processing Record 42 of Set 9 | aswan
# Processing Record 43 of Set 9 | acapulco
# Processing Record 44 of Set 9 | beni
# Processing Record 45 of Set 9 | ottersberg
# Processing Record 46 of Set 9 | katsuura
# City not found. Skipping... tapaua.
# Processing Record 47 of Set 9 | sheffield
# Processing Record 48 of Set 9 | salinas
# Processing Record 49 of Set 9 | kerewan
# Processing Record 50 of Set 9 | powell river
# Processing Record 0 of Set 10 | nuuk
# Processing Record 1 of Set 10 | bako
# Processing Record 2 of Set 10 | raudeberg
# Processing Record 3 of Set 10 | ust-kuyga
# Processing Record 4 of Set 10 | muravlenko
# Processing Record 5 of Set 10 | lompoc
# Processing Record 6 of Set 10 | dalvik
# Processing Record 7 of Set 10 | aldan
# City not found. Skipping... falealupo.
# Processing Record 8 of Set 10 | bourail
# Processing Record 9 of Set 10 | ville-marie
# City not found. Skipping... shpykiv.
# Processing Record 10 of Set 10 | kungurtug
# Processing Record 11 of Set 10 | touros
# Processing Record 12 of Set 10 | balkhash
# Processing Record 13 of Set 10 | bambous virieux
# Processing Record 14 of Set 10 | srandakan
# Processing Record 15 of Set 10 | nicoya
# Processing Record 16 of Set 10 | codrington
# Processing Record 17 of Set 10 | springbok
# Processing Record 18 of Set 10 | krasnozerskoye
# Processing Record 19 of Set 10 | lamu
# Processing Record 20 of Set 10 | tacoronte
# Processing Record 21 of Set 10 | tsumeb
# Processing Record 22 of Set 10 | tonekabon
# Processing Record 23 of Set 10 | valley station
# Processing Record 24 of Set 10 | san andres
# Processing Record 25 of Set 10 | woodward
# Processing Record 26 of Set 10 | rincon
# Processing Record 27 of Set 10 | pimenta bueno
# Processing Record 28 of Set 10 | murray bridge
# Processing Record 29 of Set 10 | mbamba
# Processing Record 30 of Set 10 | hamilton
# Processing Record 31 of Set 10 | sistranda
# Processing Record 32 of Set 10 | rzhev
# Processing Record 33 of Set 10 | whitecourt
# Processing Record 34 of Set 10 | griffith
# Processing Record 35 of Set 10 | aguadilla
# Processing Record 36 of Set 10 | zyryanka
# Processing Record 37 of Set 10 | swellendam
# Processing Record 38 of Set 10 | hidalgotitlan
# Processing Record 39 of Set 10 | lewiston
# Processing Record 40 of Set 10 | mount vernon
# Processing Record 41 of Set 10 | labrea
# Processing Record 42 of Set 10 | christchurch
# Processing Record 43 of Set 10 | kalabo
# Processing Record 44 of Set 10 | lodwar
# City not found. Skipping... chagda.
# City not found. Skipping... tarudant.
# Processing Record 45 of Set 10 | kuybysheve
# Processing Record 46 of Set 10 | labuan
# Processing Record 47 of Set 10 | saravan
# Processing Record 48 of Set 10 | san patricio
# Processing Record 49 of Set 10 | banjar
# Processing Record 50 of Set 10 | bilma
# City not found. Skipping... hendijan.
# Processing Record 0 of Set 11 | poltavka
# Processing Record 1 of Set 11 | lagoa
# Processing Record 2 of Set 11 | kardymovo
# Processing Record 3 of Set 11 | pinawa
# City not found. Skipping... phan rang.
# Processing Record 4 of Set 11 | ostersund
# Processing Record 5 of Set 11 | ambulu
# Processing Record 6 of Set 11 | umm lajj
# Processing Record 7 of Set 11 | leua
# Processing Record 8 of Set 11 | marcala
# Processing Record 9 of Set 11 | salme
# Processing Record 10 of Set 11 | neiafu
# Processing Record 11 of Set 11 | slavuta
# Processing Record 12 of Set 11 | rosarito
# Processing Record 13 of Set 11 | zabid
# Processing Record 14 of Set 11 | gumdag
# Processing Record 15 of Set 11 | marrakesh
# Processing Record 16 of Set 11 | smithers
# Processing Record 17 of Set 11 | salatrucu
# Processing Record 18 of Set 11 | nortelandia
# Processing Record 19 of Set 11 | larsnes
# Processing Record 20 of Set 11 | athabasca
# Processing Record 21 of Set 11 | tumsar
# Processing Record 22 of Set 11 | cap malheureux
# Processing Record 23 of Set 11 | yumen
# Processing Record 24 of Set 11 | maragogi
# Processing Record 25 of Set 11 | caravelas
# Processing Record 26 of Set 11 | mananjary
# Processing Record 27 of Set 11 | amahai
# City not found. Skipping... barawe.
# Processing Record 28 of Set 11 | sao filipe
# Processing Record 29 of Set 11 | port augusta
# Processing Record 30 of Set 11 | la ronge
# Processing Record 31 of Set 11 | aberdeen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({
    "City": cityname_list,
    "Lat": lat_list,
    "Lng": lng_list,
    "Max Temp": maxtemp_list,
    "Humidity": humidity_list,
    "Cloudiness": cloudiness_list,
    "Wind Speed": windspeed_list,
    "Country": country_list,
    "Date": date_list
})

weather_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Coyhaique -45.5752  -72.0662      7.34        93          75
# 1     Punta Arenas -53.1500  -70.9167      4.06        81           0
# 2          Northam  51.0333   -4.2167     15.90        88          97
# 3             Nome  64.5011 -165.4064      8.04        76          75
# 4    Fuerte Olimpo -21.0415  -57.8738     16.16        48           7
# ..             ...      ...       ...       ...       ...         ...
# 536         Amahai  -3.3333  128.9167     27.12        79          99
# 537     São Filipe  14.8961  -24.4956     25.91        82          16
# 538   Port Augusta -32.5000  137.7667     17.70        49           1
# 539       La Ronge  55.1001 -105.2842     13.14        58           0
# 540       Aberdeen  57.1437   -2.0981      9.16        93          74
#
#      Wind Speed Country        Date
# 0          1.03      CL  1662874424
# 1          3.60      CL  1662874425
# 2          3.72      GB  1662874425
# 3          4.12      US  1662874426
# 4          2.25      PY  1662874427
# ..          ...     ...         ...
# 536        2.06      ID  1662874781
# 537        0.51      CV  1662874782
# 538        5.69      AU  1662874782
# 539        2.57      CA  1662874783
# 540        0.51      GB  1662874784
#
# [541 rows x 9 columns]

# %%
#Export the city data into a .csv.
weather_df.to_csv(r'/Users/carlv/Desktop/DA_Class_Folder/Week 6 - Python APIs/Week 6 Module Challenge/python-api-challenge/output_data/cities.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
#SKIPPED

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#SKIPPED

# %% [markdown]
# ## Plotting the Data
# * Use proper labelling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], facecolor = "steelblue", edgecolor = "black")

plt.title("Latitude vs Temperature (11/09/22)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (Celsius)")
plt.grid(linestyle="-", linewidth=1, alpha=0.5)

plt.savefig("../output_data/Fig1.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], facecolor = "steelblue", edgecolor = "black")

plt.title("Latitude vs Humidity (11/09/22)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle="-", linewidth=1, alpha=0.5)

plt.savefig("../output_data/Fig2.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

plt.title("Latitude vs Cloudiness (11/09/22)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(linestyle="-", linewidth=1, alpha=0.5)

plt.savefig("../output_data/Fig3.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], facecolor = "steelblue", edgecolor = "black")

plt.title("Latitude vs Wind Speed (11/09/22)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(linestyle="-", linewidth=1, alpha=0.5)

plt.savefig("../output_data/Fig4.png")

# %% [markdown]
# ## Linear Regression

# %%
nth_hemi_df = weather_df.loc[weather_df["Lat"] >= 0]
sth_hemi_df = weather_df.loc[weather_df["Lat"] < 0]

# %%
corr1 = st.pearsonr(tumour_avg["Weight (g)"], tumour_avg["Tumour Volume (mm3)"])[0]
print(f"The correlation between mouse weight and average tumour volume is {correlation} ")

# %% [markdown]
# ###  Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(nth_hemi_df["Lat"], nth_hemi_df["Max Temp"], facecolor = "steelblue")

plt.title("Northern Hemisphere - Latitude vs Temperature Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (Celsius)")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(nth_hemi_df["Lat"], nth_hemi_df["Max Temp"])
regress_values = nth_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(nth_hemi_df["Lat"], regress_values, "r-",)
plt.annotate(line_eq, (0,5), fontsize=15, color="red")
# Out:
# Text(0, 5, 'y = -0.35x + 32.99')

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(sth_hemi_df["Lat"], sth_hemi_df["Max Temp"], facecolor = "steelblue")

plt.title("Southern Hemisphere - Latitude vs Temperature Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (Celsius)")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(sth_hemi_df["Lat"], sth_hemi_df["Max Temp"])
regress_values = sth_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(sth_hemi_df["Lat"], regress_values, "r-",)
plt.annotate(line_eq, (-50,30), fontsize=15, color="red")
# Out:
# Text(-50, 30, 'y = 0.44x + 29.25')

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(nth_hemi_df["Lat"], nth_hemi_df["Humidity"], facecolor = "steelblue")

plt.title("Northern Hemisphere - Latitude vs Humidity Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(nth_hemi_df["Lat"], nth_hemi_df["Humidity"])
regress_values = nth_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(nth_hemi_df["Lat"], regress_values, "r-",)
plt.annotate(line_eq, (0,5), fontsize=15, color="red")
# Out:
# Text(0, 5, 'y = 0.01x + 71.8')

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(sth_hemi_df["Lat"], sth_hemi_df["Humidity"], facecolor = "steelblue")

plt.title("Southern Hemisphere - Latitude vs Humidity Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(sth_hemi_df["Lat"], sth_hemi_df["Humidity"])
regress_values = sth_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(sth_hemi_df["Lat"], regress_values, "r-",)
plt.annotate(line_eq, (-55,25), fontsize=15, color="red")
# Out:
# Text(-55, 25, 'y = -0.12x + 66.77')

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(nth_hemi_df["Lat"], nth_hemi_df["Cloudiness"], facecolor = "steelblue")

plt.title("Northern Hemisphere - Latitude vs Cloudiness Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(nth_hemi_df["Lat"], nth_hemi_df["Cloudiness"])
regress_values = nth_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(nth_hemi_df["Lat"], regress_values, "r-",)
plt.annotate(line_eq, (8,65), fontsize=15, color="red")
# Out:
# Text(8, 65, 'y = 0.2x + 52.55')

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(sth_hemi_df["Lat"], sth_hemi_df["Cloudiness"], facecolor = "steelblue")

plt.title("Southern Hemisphere - Latitude vs Cloudiness Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(sth_hemi_df["Lat"], sth_hemi_df["Cloudiness"])
regress_values = sth_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(sth_hemi_df["Lat"], regress_values, "r-",)
plt.annotate(line_eq, (-50,85), fontsize=15, color="red")
# Out:
# Text(-50, 85, 'y = 0.32x + 47.92')

# %% [markdown]
# ### Wind Speed (m/s) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(nth_hemi_df["Lat"], nth_hemi_df["Wind Speed"], facecolor = "steelblue")

plt.title("Northern Hemisphere - Latitude vs Wind Speed Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(nth_hemi_df["Lat"], nth_hemi_df["Wind Speed"])
regress_values = nth_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(nth_hemi_df["Lat"], regress_values, "r-",)
plt.annotate(line_eq, (0,15), fontsize=15, color="red")
# Out:
# Text(0, 15, 'y = 0.01x + 3.26')

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(sth_hemi_df["Lat"], sth_hemi_df["Wind Speed"], facecolor = "steelblue")

plt.title("Southern Hemisphere - Latitude vs Wind Speed Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(sth_hemi_df["Lat"], sth_hemi_df["Wind Speed"])
regress_values = sth_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(sth_hemi_df["Lat"], regress_values, "r-",)
plt.annotate(line_eq, (-50,9), fontsize=15, color="red")
# Out:
# Text(-50, 9, 'y = 0.0x + 3.45')
